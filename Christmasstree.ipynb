# %% [markdown]
# <a href="https://colab.research.google.com/github/echeruiyot/ADS-Assignment-1/blob/main/Christmasstree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("    *")
print("   ***")
print("  *****")
print (" *******")
print("*********")
# Out:
#     *
#    ***
#   *****
#  *******
# *********

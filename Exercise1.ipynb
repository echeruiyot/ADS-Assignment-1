# %% [markdown]
# <a href="https://colab.research.google.com/github/echeruiyot/ADS-Assignment-1/blob/main/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=4
num2=10
num3=(num1+num2)
print (num3)
# Out:
# 14

# %% [markdown]
# Write a program to accept a numeric input from the user

# %%
num = int(input("Enter a number: "))
num = num + 1
print("Result:", num)

# %% [markdown]
# Write a program to get the result by adding two integers given by the user.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

sum = num1 + num2

print("Sum:", sum)

# %% [markdown]
# Write a program to get the result by diving two numbers given by the user.

# %%
num1 = int (input ("Enter the first number: "))
num2 = int(input ("Enter the second number: "))
divide = num1/num2
print("Division is", divide)

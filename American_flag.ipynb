# %% [markdown]
# <a href="https://colab.research.google.com/github/echeruiyot/ADS-Assignment-1/blob/main/American_flag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First 4 lines: 7 stars + 34 dashes
for _ in range(4):
    print("*" * 7 + "-" * 34)

# Next 2 lines: only dashes (45 total)
for _ in range(2):
    print("-" * 45)
# Out:
# *******----------------------------------
# *******----------------------------------
# *******----------------------------------
# *******----------------------------------
# ---------------------------------------------
# ---------------------------------------------
